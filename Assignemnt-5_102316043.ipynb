# %% [markdown]
# # Assignment 5

# %%
import numpy as np

# %% [markdown]
# Ques 1) For the array gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]'), Find
# 1. Sum of all elements
# 2. Sum of all elements row-wise
# 3. Sum of all elements column-wise

# %%
gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]')
print(f"1. {np.sum(gfg)}")
print(f"2. {np.sum(gfg, axis=1)}")
print(f"3. {np.sum(gfg, axis=0)}")
# Out:
# 1. 45
# 2. [[14]
#  [16]
#  [15]]
# 3. [[20  9 16]]

# %% [markdown]
# Ques 2)
#
# (a) For the array: `array = np.array([10, 52, 62, 16, 16, 54, 453])`, find
# 1. Sorted array
# 2. Indices of sorted array
# 3. 4 smallest elements
# 4. 5 largest elements
#
# (b) For the array: `array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0])`, find
# 1. Integer elements only
# 2. Float elements only

# %%
arr_a = np.array([10,52,62,16,16,54,453])
# 1.
arr_a.sort()
print(f"a.\n1. {arr_a}")

# 2.
arr_org = np.array([10,52,62,16,16,54,453])
indices = np.argsort(arr_org)
print(f"2. {indices}")

print(f"3. {arr_a[:4]}")
print(f"4. {arr_a[-5:]}")

arr_b = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0])
print(f"\nb.\n1. {arr_b[arr_b == arr_b.astype(int)]}")
print(f"2. {arr_b[(arr_b != arr_b.astype(int)) & (arr_b == arr_b.astype(float))]}")
# Out:
# a.
# 1. [ 10  16  16  52  54  62 453]
# 2. [0 3 4 1 5 2 6]
# 3. [10 16 16 52]
# 4. [ 16  52  54  62 453]
#
# b.
# 1. [1. 2. 3. 2.]
# 2. [1.2 2.2]

# %% [markdown]
# Ques 3) You are given a weekly sales dataset and need to perform various operations using NumPy broadcasting.
#
# a) Generate your unique sales dataset:
# - Take the sum of the ASCII values of the initials of your first and last name. Call this value X. (If your initials are A B → ASCII sum = 65 + 66 = 131 → sales = [131, 181, 231, 281, 331].)
# - Create a NumPy array `sales` with values [X, X+50, X+100, X+150, X+200].
#
# b) Compute your personalized tax rate as `((X % 5) + 5) / 100`.
# - Use broadcasting to apply this tax rate to each sales value.
#
# c) Adjust sales based on discount:
# - If sales < X+100, apply a 5% discount.
# - If sales >= X+100, apply a 10% discount.
#
# d) Expand sales data for multiple weeks:
# - Create a 3×5 matrix representing three weeks of sales by stacking sales three times using broadcasting.
# - Increase sales by 2% per week using element-wise broadcasting.

# %%
# a.
X = ord('I') + ord('S')
sales = np.array([X, X + 50, X + 100, X + 150, X + 200])
print(f"a. Dataset generated is: {sales}")

# b.
taxed = ((sales % 5) + 5) / 100
print(f"b. Sales after broadcasting tax on it is :{taxed}")

# c.
discount = np.where(sales < X + 100, sales * 0.95, sales * 0.90)
print(f"c. Sales after applying discount: {discount}")

# d.
expanded_sales = np.resize(sales, [3, 5])
for i in range(1, expanded_sales.shape[0]):
    expanded_sales[i] = expanded_sales[i-1] * 1.02
print(f"d. Expanded sales data for multiple weeks after 2% increase per week: \n{expanded_sales}")
# Out:
# a. Dataset generated is: [156 206 256 306 356]
# b. Sales after broadcasting tax on it is :[0.06 0.06 0.06 0.06 0.06]
# c. Sales after applying discount: [148.2 195.7 230.4 275.4 320.4]
# d. Expanded sales data for multiple weeks after 2% increase per week:
# [[156 206 256 306 356]
#  [159 210 261 312 363]
#  [162 214 266 318 370]]

# %% [markdown]
# Ques 4) Generate x values using `np.linspace()` from -10 to 10 with 100 points. Use each function from the list below and compute y values using NumPy:
# - \(Y = x^2\)
# - \(Y = sin(x)\)
# - \(Y = e^x\)
# - \(Y = log(|x| + 1)\)
#
# Plot the chosen function using Matplotlib. Add title, labels, and grid for clarity.

# %%
import matplotlib.pyplot as plt

x_vals = np.linspace(-10, 10, 100)

y1 = x_vals ** 2
y2 = np.sin(x_vals)
y3 = np.exp(x_vals)
y4 = np.log(np.abs(x_vals) + 1)

plt.plot(x_vals, y1, label='y = x^2')
plt.plot(x_vals, y2, label='y = sin(x)')
plt.plot(x_vals, y3, label='y = e^x')
plt.plot(x_vals, y4, label='y = log(|x| + 1)')
plt.title('Answer 4 - Ishtpreet')
plt.xlabel('x')
plt.xlim(-10, 10)  # Set the range for x-axis
plt.ylim(-5, 50)  # Set the range for y-axis
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.show()
