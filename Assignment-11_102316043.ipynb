# %% [markdown]
# # Assignment 11
# #### - Ishtpreet Singh, 102316043

# %% [markdown]
# Q1. Design a Cognitive Assistant for Reading Labels of medicine bottle (You can download
# Dataset from Internet)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Q2. Design an Emotion-aware Cognitive Assistant using Facial Expression Detection

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
